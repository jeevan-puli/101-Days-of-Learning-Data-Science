# %% [markdown]
# # Discretization:
#
# - Discretization is the process of transforming continuous variables into discrete variables by creating a set of contiguous intervals that span the range of the variable's values.
# - Discretization is alos callled binning, where bin is an alternatiove name for interval.
# - Discretization helps handle outliers by placing these values into the lower or higher intervals, together with the remaining inlier values of the distribution. Thus, these outlier observations no longer differ from the rest of the values at the tails of the distribution, as they are now all together in the same interval / bucket.
# - In addition, by creating appropriate bins or intervals, discretization can help spread the values of a akewd variable across a set of bins with equal number of observations.

# %%
import pandas as pd

# %%
df = pd.read_csv("stroke prediction.csv")
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0  30669    Male   3.0             0              0           No
# 1  30468    Male  58.0             1              0          Yes
# 2  16523  Female   8.0             0              0           No
# 3  56543  Female  70.0             0              0          Yes
# 4  46136    Male  14.0             0              0           No
#
#       work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0      children          Rural              95.12  18.0              NaN
# 1       Private          Urban              87.96  39.2     never smoked
# 2       Private          Urban             110.89  17.6              NaN
# 3       Private          Rural              69.04  35.9  formerly smoked
# 4  Never_worked          Rural             161.28  19.1              NaN
#
#    stroke
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.shape
# Out:
# (43400, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43400 entries, 0 to 43399
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 43400 non-null  int64
#  1   gender             43400 non-null  object
#  2   age                43400 non-null  float64
#  3   hypertension       43400 non-null  int64
#  4   heart_disease      43400 non-null  int64
#  5   ever_married       43400 non-null  object
#  6   work_type          43400 non-null  object
#  7   Residence_type     43400 non-null  object
#  8   avg_glucose_level  43400 non-null  float64
#  9   bmi                41938 non-null  float64
#  10  smoking_status     30108 non-null  object
#  11  stroke             43400 non-null  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 4.0+ MB

# %%
df["stroke"].value_counts()
# Out:
# 0    42617
# 1      783
# Name: stroke, dtype: int64

# %% [markdown]
# ### Creating Bins

# %%
intervals = [0,12,19,30,60,90]   # This is used to cut, cut = 0-12,12-19,19-30,30-60,60-90
categories = ["child", "teenager", "young_adult", "middle_aged", "senior_citizen"]  #each cut should be named with categories. So no of cuts should match categories.

# %% [markdown]
# ## Discretization

# %%
df["age_category"] = pd.cut(df["age"], bins = intervals, labels = categories)

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0  30669    Male   3.0             0              0           No
# 1  30468    Male  58.0             1              0          Yes
# 2  16523  Female   8.0             0              0           No
# 3  56543  Female  70.0             0              0          Yes
# 4  46136    Male  14.0             0              0           No
#
#       work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0      children          Rural              95.12  18.0              NaN
# 1       Private          Urban              87.96  39.2     never smoked
# 2       Private          Urban             110.89  17.6              NaN
# 3       Private          Rural              69.04  35.9  formerly smoked
# 4  Never_worked          Rural             161.28  19.1              NaN
#
#    stroke    age_category
# 0       0           child
# 1       0     middle_aged
# 2       0           child
# ...

# %%
df[["age","age_category"]]
# Out:
#         age    age_category
# 0       3.0           child
# 1      58.0     middle_aged
# 2       8.0           child
# 3      70.0  senior_citizen
# 4      14.0        teenager
# ...     ...             ...
# 43395  10.0           child
# 43396  56.0     middle_aged
# 43397  82.0  senior_citizen
# 43398  40.0     middle_aged
# 43399  82.0  senior_citizen
#
# [43400 rows x 2 columns]

# %%
df["age_category"].value_counts()
# Out:
# middle_aged       18653
# senior_citizen    10511
# young_adult        5725
# child              5326
# teenager           3185
# Name: age_category, dtype: int64

# %%
pd.crosstab(df.stroke,df.age_category) ##Option 1

#pd.crosstab(df["stroke"],df["age_category"])
# Out:
# age_category  child  teenager  young_adult  middle_aged  senior_citizen
# stroke
# 0              5325      3184         5723        18453            9932
# 1                 1         1            2          200             579

# %%
pd.crosstab(df.age_category,df.stroke, margins=True)
# Out:
# stroke              0    1    All
# age_category
# child            5325    1   5326
# teenager         3184    1   3185
# young_adult      5723    2   5725
# middle_aged     18453  200  18653
# senior_citizen   9932  579  10511
# All             42617  783  43400

# %%
 pd.crosstab(df.stroke,df.ever_married)
# Out:
# ever_married     No    Yes
# stroke
# 0             15382  27235
# 1                80    703

# %%
 pd.crosstab(df.ever_married,df.stroke,margins = True)
# Out:
# stroke            0    1    All
# ever_married
# No            15382   80  15462
# Yes           27235  703  27938
# All           42617  783  43400
